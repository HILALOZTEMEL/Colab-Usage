# %% [markdown]
# <a href="https://colab.research.google.com/github/HILALOZTEMEL/Colab-Usage/blob/main/virtualenv_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install virtualenv
# !virtualenv theanoEnv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 10.1 MB 13.7 MB/s
# ...
#      |████████████████████████████████| 466 kB 46.1 MB/s
# ...
# created virtual environment CPython3.7.13.final.0-64 in 1004ms
#   creator CPython3Posix(dest=/content/theanoEnv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==22.1.2, setuptools==62.6.0, wheel==0.37.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source /content/theanoEnv/bin/activate; pip3 install theano
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 41.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 65.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 12.0 MB/s eta 0:00:00
# ...
#   Created wheel for theano: filename=Theano-1.0.5-py3-none-any.whl size=2668109 sha256=666473cd00d7656e7ca19785cd6bc499b63d9f467e62dcab27c0df0a6a6b8e51
#   Stored in directory: /root/.cache/pip/wheels/26/68/6f/745330367ce7822fe0cd863712858151f5723a0a5e322cc144
# Successfully built theano
# ...

# %%
# !source /content/theanoEnv/bin/activate; pip3 list
# Out:
# Package    Version
# ---------- -------
# numpy      1.21.6
# pip        22.1.2
# scipy      1.7.3
# setuptools 62.6.0
# six        1.16.0
# Theano     1.0.5
# wheel      0.37.1

# %%
# !source /content/theanoEnv/bin/activate; pip3 install robotframework; pip3 list; python3 -m robot --help
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 639.4/639.4 kB 23.9 MB/s eta 0:00:00
# ...
# Package        Version
# -------------- -------
# numpy          1.21.6
# pip            22.1.2
# robotframework 5.0.1
# scipy          1.7.3
# setuptools     62.6.0
# six            1.16.0
# Theano         1.0.5
# wheel          0.37.1
# Robot Framework -- A generic automation framework
#
# Version:  5.0.1 (Python 3.7.13 on linux)
#
# Usage:  robot [options] paths
#    or:  python -m robot [options] paths
#    or:  python path/to/robot [options] paths
#
# Robot Framework is a generic open source automation framework for acceptance
# testing, acceptance test-driven development (ATDD) and robotic process
# automation (RPA). It has simple, easy-to-use syntax that utilizes the
# keyword-driven automation approach. Keywords adding new capabilities are
# ...
